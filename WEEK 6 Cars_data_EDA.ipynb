# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\IMP DOC\cars_ds_final.csv",index_col=0)

# %%
df.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1276 entries, 0 to 1275
# Columns: 140 entries, Make to Electric_Range
# dtypes: float64(6), object(134)
# memory usage: 1.4+ MB

# %%
df.info
# Out:
# <bound method DataFrame.info of             Make      Model        Variant Ex-Showroom_Price Displacement  \
# 0           Tata  Nano Genx             Xt      Rs. 2,92,667       624 cc
# 1           Tata  Nano Genx             Xe      Rs. 2,36,447       624 cc
# 2           Tata  Nano Genx        Emax Xm      Rs. 2,96,661       624 cc
# 3           Tata  Nano Genx            Xta      Rs. 3,34,768       624 cc
# 4           Tata  Nano Genx             Xm      Rs. 2,72,223       624 cc
# ...          ...        ...            ...               ...          ...
# 1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000      1498 cc
# 1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000      1498 cc
# 1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000      1497 cc
# 1274       Honda       City   V Cvt Petrol     Rs. 12,01,000      1497 cc
# 1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560      3200 cc
#
# ...

# %%
df.shape
# Out:
# (1276, 140)

# %%
df.isna().sum()
# Out:
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement           12
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 140, dtype: int64

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Variant', 'Ex-Showroom_Price', 'Displacement',
#        'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration', 'Emission_Norm',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=140)

# %%
df.rename(columns = str.lower,inplace=True)
df.columns
# Out:
# Index(['make', 'model', 'variant', 'ex-showroom_price', 'displacement',
#        'cylinders', 'valves_per_cylinder', 'drivetrain',
#        'cylinder_configuration', 'emission_norm',
#        ...
#        'leather_wrapped_steering', 'automatic_headlamps', 'engine_type',
#        'asr_/_traction_control', 'cruise_control', 'usb_ports',
#        'heads-up_display', 'welcome_lights', 'battery', 'electric_range'],
#       dtype='object', length=140)

# %%
df['make'].isna().sum()
# Out:
# 75

# %%
df['make'].value_counts()
# Out:
# Maruti Suzuki       149
# Hyundai             130
# Mahindra            119
# Tata                100
# Toyota               82
# Honda                64
# Skoda                43
# Ford                 43
# Bmw                  37
# Renault              36
# Volkswagen           34
# Audi                 31
# Nissan               29
# Jeep                 28
# Land Rover Rover     27
# Fiat                 23
# Jaguar               22
# Kia                  21
# Volvo                18
# Datsun               15
# Porsche              14
# Maruti Suzuki R      14
# Lamborghini          13
# Mg                   13
# Icml                 11
# Land Rover           10
# Lexus                10
# Mini                 10
# Maserati              9
# Ferrari               8
# Mitsubishi            7
# Bentley               6
# Premier               6
# Force                 6
# Isuzu                 5
# Aston Martin          3
# Bajaj                 2
# Bugatti               2
# ...

# %%
df['make'] = df['make'].replace('Land Rover Rover','Land Rover')

# %%
df[df['make'] == 'Land Rover Rover']
# Out:
# Empty DataFrame
# ...

# %%
df['make'] = df['make'].replace('Maruti Suzuki R','Maruti Suzuki')

# %%
df[df['make'] == 'Maruti Suzuki R']
# Out:
# Empty DataFrame
# ...

# %%
df['make'].value_counts()
# Out:
# Maruti Suzuki    163
# Hyundai          130
# Mahindra         119
# Tata             100
# Toyota            82
# Honda             64
# Skoda             43
# Ford              43
# Land Rover        37
# Bmw               37
# Renault           36
# Volkswagen        34
# Audi              31
# Nissan            29
# Jeep              28
# Fiat              23
# Jaguar            22
# Kia               21
# Volvo             18
# Datsun            15
# Porsche           14
# Mg                13
# Lamborghini       13
# Icml              11
# Mini              10
# Lexus             10
# Maserati           9
# Ferrari            8
# Mitsubishi         7
# Bentley            6
# Force              6
# Premier            6
# Isuzu              5
# Aston Martin       3
# Bugatti            2
# Bajaj              2
# Dc                 1
# Name: make, dtype: int64

# %%
df['model'].isna().sum()
# Out:
# 0

# %%
df['model'].value_counts()
# Out:
# Nexon                              24
# Kuv100 Nxt                         22
# Compass                            21
# Xuv500                             21
# Amaze                              20
#                                    ..
# Lc 500H                             1
# Lx 450D                             1
# Mercedes-Benz S-Class Cabriolet     1
# R8                                  1
# Montero                             1
# Name: model, Length: 263, dtype: int64

# %%
df['usb_ports'].value_counts()
# Out:
# 1.0    12
# 2.0    11
# 3.0     6
# Name: usb_ports, dtype: int64

# %% [markdown]
# ['make','model','ex-showroom_price','body_type','displacement', 'cylinders', 'fuel_system', 'fuel_tank_capacity', 'fuel_type',  'city_mileage',  'seating_capacity','basic_warranty', 'child_safety_locks', 'number_of_airbags', 'parking_assistance',  'navigation_system']

# %%
df['cylinders'].value_counts()
# Out:
# 4.0     789
# 3.0     213
# 6.0     106
# 8.0      53
# 12.0     21
# 5.0      10
# 10.0     10
# 2.0       6
# 16.0      2
# Name: cylinders, dtype: int64

# %%
df['fuel_system'].value_counts()
# Out:
# Injection    1264
# PGM - Fi        4
# Name: fuel_system, dtype: int64

# %%
df['fuel_tank_capacity'].value_counts()
# Out:
# 45 litres      125
# 35 litres      124
# 50 litres       94
# 60 litres       91
# 37 litres       79
#               ...
# 36 litres        1
# 90.5 litres      1
# 87 litres        1
# 72 litres        1
# 96 litres        1
# Name: fuel_tank_capacity, Length: 63, dtype: int64

# %%
df['city_mileage'].value_counts()
# Out:
# 12 km/litre      38
# 16 km/litre      30
# 18 km/litre      26
# 14 km/litre      20
# 23 km/litre      19
#                  ..
# 8.69 km/litre     1
# 4 km/litre        1
# 3 km/litre        1
# 4.38 km/litre     1
# 8.25 km/litre     1
# Name: city_mileage, Length: 164, dtype: int64

# %%
df['seating_capacity'].value_counts()
# Out:
# 5.0     915
# 7.0     183
# 4.0      70
# 2.0      39
# 6.0      26
# 9.0      19
# 8.0      17
# 16.0      1
# Name: seating_capacity, dtype: int64

# %%
df['basic_warranty'].value_counts()
# Out:
# 2 years / Unlimited Kms                                            132
# 3 years / Unlimited Kms                                            118
# 2 years /40000 Kms (years/distance whichever comes first)          110
# 3 years /100000 Kms (years/distance whichever comes first)          85
# 3 Years/1,00,000 Kms (Whichever comes earlier)                      77
# 2 Years / 40,000 Kms (Whichever comes earlier)                      54
# 2 Years / 100,000 Kms (whichever comes first)                       51
# 2 years /75000 Kms (years/distance whichever comes first)           31
# 2 years /1,00,000 Kms (years/distance whichever comes first)        30
# 24 months /50000 Kms (whichever comes first)                        20
# 2 years /50000 Kms (years/distance whichever comes first)           18
# 2 Years / 75,000 KM (whichever is earlier)                          17
# 2 Years / 50,000 Kms (Whichever comes earlier)                      16
# ...

# %%
df['child_safety_locks'].value_counts()
# Out:
# Yes    1201
# Name: child_safety_locks, dtype: int64

# %%
df['number_of_airbags'].value_counts()
# Out:
# 2.0     627
# 6.0     202
# 8.0      92
# 7.0      65
# 1.0      57
# 4.0      40
# 9.0      21
# 3.0      17
# 10.0     16
# 14.0      3
# 5.0       1
# Name: number_of_airbags, dtype: int64

# %%
df['navigation_system'].value_counts()
# Out:
# Yes    683
# Name: navigation_system, dtype: int64

# %%
new_df = df[['make','model','ex-showroom_price','body_type','displacement', 'cylinders', 'fuel_system', 'fuel_tank_capacity', 'fuel_type',  'city_mileage',  'seating_capacity','basic_warranty', 'child_safety_locks', 'number_of_airbags', 'parking_assistance',  'navigation_system']]

# %%
new_df.shape
# Out:
# (1276, 16)

# %%
new_df.isna().sum()
# Out:
# make                   75
# model                   0
# ex-showroom_price       0
# body_type               6
# displacement           12
# cylinders               0
# fuel_system             0
# fuel_tank_capacity     69
# fuel_type               0
# city_mileage            0
# seating_capacity        0
# basic_warranty          0
# child_safety_locks      0
# number_of_airbags       0
# parking_assistance    290
# navigation_system       0
# dtype: int64

# %%
new_df['parking_assistance'].isna().sum()
# Out:
# 290

# %%
new_df['parking_assistance'].fillna(df['parking_assistance'].mode()[0], inplace=True)
# Out:
# C:\Users\ns118\AppData\Local\Temp\ipykernel_24964\1384780986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['parking_assistance'].fillna(df['parking_assistance'].mode()[0], inplace=True)

# %%
new_df['make'].isna().sum()
# Out:
# 75

# %%
new_df['make'].fillna(df['make'].mode()[0], inplace=True)
# Out:
# C:\Users\ns118\AppData\Local\Temp\ipykernel_24964\3481075203.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['make'].fillna(df['make'].mode()[0], inplace=True)

# %%
new_df['parking_assistance'].fillna(df['parking_assistance'].mode()[0], inplace=True)
# Out:
# C:\Users\ns118\AppData\Local\Temp\ipykernel_24964\1384780986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['parking_assistance'].fillna(df['parking_assistance'].mode()[0], inplace=True)

# %%
new_df['displacement'].isna().sum()
# Out:
# 12

# %%
new_df['displacement'].fillna(df['displacement'].mode()[0], inplace=True)
# Out:
# C:\Users\ns118\AppData\Local\Temp\ipykernel_24964\2829548503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['displacement'].fillna(df['displacement'].mode()[0], inplace=True)

# %%
new_df['fuel_tank_capacity'].isna().sum()
# Out:
# 69

# %%
new_df['fuel_tank_capacity'].fillna(df['fuel_tank_capacity'].mode()[0], inplace=True)
# Out:
# C:\Users\ns118\AppData\Local\Temp\ipykernel_24964\2526676211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['fuel_tank_capacity'].fillna(df['fuel_tank_capacity'].mode()[0], inplace=True)

# %%
new_df.isna().sum()
# Out:
# make                  0
# model                 0
# ex-showroom_price     0
# body_type             6
# displacement          0
# cylinders             0
# fuel_system           0
# fuel_tank_capacity    0
# fuel_type             0
# city_mileage          0
# seating_capacity      0
# basic_warranty        0
# child_safety_locks    0
# number_of_airbags     0
# parking_assistance    0
# navigation_system     0
# dtype: int64

# %%
new_df.head()
# Out:
#    make      model ex-showroom_price  body_type displacement  cylinders  \
# 0  Tata  Nano Genx      Rs. 2,92,667  Hatchback       624 cc        2.0
# 1  Tata  Nano Genx      Rs. 2,36,447  Hatchback       624 cc        2.0
# 2  Tata  Nano Genx      Rs. 2,96,661  Hatchback       624 cc        2.0
# 3  Tata  Nano Genx      Rs. 3,34,768  Hatchback       624 cc        2.0
# 4  Tata  Nano Genx      Rs. 2,72,223  Hatchback       624 cc        2.0
#
#   fuel_system fuel_tank_capacity fuel_type    city_mileage  seating_capacity  \
# 0   Injection          24 litres    Petrol  ?23.6 km/litre               4.0
# 1   Injection          24 litres    Petrol  ?23.6 km/litre               4.0
# 2   Injection          15 litres       CNG     12 km/litre               4.0
# 3   Injection          24 litres    Petrol  ?23.6 km/litre               4.0
# 4   Injection          24 litres    Petrol  ?23.6 km/litre               4.0
#
# ...

# %%
new_df[new_df['body_type'].isna()]
# Out:
#           make          model ex-showroom_price body_type displacement  \
# 239   Mahindra     Alturas G4     Rs. 27,70,150       NaN      2157 cc
# 843   Maserati         Ghibli   Rs. 1,33,87,856       NaN      2987 cc
# 844   Maserati         Ghibli   Rs. 1,38,81,858       NaN      2987 cc
# 845   Maserati         Ghibli   Rs. 1,42,47,814       NaN      2987 cc
# 1253   Porsche  Cayenne Coupe   Rs. 1,31,51,000       NaN      2995 cc
# 1254   Porsche  Cayenne Coupe   Rs. 1,97,63,000       NaN      2995 cc
#
#       cylinders fuel_system fuel_tank_capacity fuel_type city_mileage  \
# 239    4.000000   Injection          70 litres    Diesel  12 km/litre
# 843    4.380992   Injection          70 litres    Diesel  12 km/litre
# 844    4.380992   Injection          70 litres    Diesel  12 km/litre
# 845    4.380992   Injection          70 litres    Diesel  12 km/litre
# 1253   6.000000   Injection          75 litres    Petrol  12 km/litre
# ...

# %%
                ################ VISUALIZATION ################

# %%
# Histograms
new_df.hist(figsize=(20,20),bins=20)
plt.show()

# %%
# Pie Chart
new_df['fuel_type'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='fuel_type'>

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 5))
new_df['make'].value_counts().plot(kind='bar', title='Make')
plt.show()

# %%
plt.figure(figsize=(10, 5))
new_df['fuel_type'].value_counts().plot(kind='bar', title='Fuel_type')
plt.show()

# %%
plt.figure(figsize=(10, 5))
new_df['seating_capacity'].value_counts().plot(kind='bar', title='Seating_capacity')
plt.show()

# %%
plt.figure(figsize=(10, 5))
new_df['number_of_airbags'].value_counts().plot(kind='bar', title='Number_of_airbags')
plt.show()

# %%
# BOXPLOT


plt.figure(figsize=(10, 6))  
plt.boxplot(new_df['make'].value_counts())
plt.title('Boxplot of Make Counts')
plt.xlabel('Make')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))  
plt.boxplot(new_df['model'].value_counts())
plt.title('Boxplot of model Counts')
plt.xlabel('model')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))  
plt.boxplot(new_df['fuel_type'].value_counts())
plt.title('Boxplot of Fuel_type Counts')
plt.xlabel('Fuel')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))  
plt.boxplot(new_df['seating_capacity'].value_counts())
plt.title('Boxplot of Seating_capacity Counts')
plt.xlabel('Seating_Capacity')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))  
plt.boxplot(new_df['basic_warranty'].value_counts())
plt.title('Boxplot of Basic_warranty Counts')
plt.xlabel('B.W')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.grid(True)
plt.show()

# %%
# Comparring  box plot
plt.figure(figsize=(10, 6))  
new_df.boxplot()
plt.title('Boxplot of 3 Columns')
plt.xticks(rotation=45)  
plt.grid(True)
plt.show()

# %%
#  Count plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(15, 6))  
sns.countplot(data=new_df, x='make')
plt.title('Count Plot of Make')
plt.xlabel('Make')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 6))  
sns.countplot(data=new_df, x='fuel_type')
plt.title('Count Plot of Fuel_type')
plt.xlabel('Fuel')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 6))  
sns.countplot(data=new_df, x='seating_capacity')
plt.title('Count Plot of Seating_Capacity')
plt.xlabel('Seater')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 6))  
sns.countplot(data=new_df, x='number_of_airbags')
plt.title('Count Plot of number_of_airbags')
plt.xlabel('N.O.A')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.grid(True)
plt.show()

# %%
### Correlation Matrix

# %%
numeric_df = new_df.select_dtypes(include='number')

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Plot the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
### Scatter Plot

# %%
plt.figure(figsize=(10, 6)) 
sns.scatterplot(data=new_df, x='ex-showroom_price', y='make')
plt.title('Scatter Plot')
plt.xlabel('X Column')
plt.ylabel('Y Column')
plt.grid(True)
plt.show()

# %%
# Pair Plots

# %%
plt.figure(figsize=(12, 8))  
sns.pairplot(new_df)
plt.title('Pair Plot')
plt.show()

# %%
# Bar charts with Hue

# %%
plt.figure(figsize=(10, 6)) 
sns.barplot(data=new_df, x='seating_capacity', y='cylinders', hue='number_of_airbags')
plt.title('Bar Chart with number_of_airbags')
plt.xlabel('seating_capacity')
plt.ylabel('cylinders')
plt.legend(title='NOA')
plt.show()

# %%
# Heatmaps

# %%
plt.figure(figsize=(10, 8)) 
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# joint plots

# %%
sns.jointplot(data=df, x='cylinders', y='seating_capacity', kind='scatter')
plt.title('Joint Plot')
plt.show()

# %%
# boxplots with Hue

# %%
plt.figure(figsize=(10, 6))  
sns.boxplot(data=new_df, x='seating_capacity', y='cylinders', hue='number_of_airbags')
plt.title('Box Plot with Hue')
plt.xlabel('seating_capacity')
plt.ylabel('cylinders')
plt.legend(title='NOA')
plt.show()

# %%
# Voilin Plots

# %%
plt.figure(figsize=(10, 6))  
sns.violinplot(data=new_df, x='seating_capacity', y='cylinders', hue='number_of_airbags')
plt.title('Violin Plot')
plt.xlabel('seating_capacity')
plt.ylabel('cylinders')
plt.legend(title='NOA')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/IMP DOC/train.csv")

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.isna().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df[df['Postal Code'].isna()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %%
df['Postal Code'].fillna('05401', inplace=True)

# %%
df[df['Postal Code'].isna()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales]
# Index: []

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Row ID           9800
# Order ID         4922
# Order Date       1230
# Ship Date        1326
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              529
# State              49
# Postal Code       627
# Region              4
# Product ID       1861
# Category            3
# Sub-Category       17
# Product Name     1849
# Sales            5757
# dtype: int64

# %%
data=df.copy()

# %%
data.drop(['Row ID', 'Order ID', 'Customer ID', 'Country', 'Product ID', 'Product Name'], axis=1, inplace=True)

# %%
# Variables

# %%
# Ordinal

# %%
data['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
data['Ship Mode'].value_counts(normalize=True, dropna=False)
# Out:
# Standard Class    0.597857
# Second Class      0.194082
# First Class       0.153163
# Same Day          0.054898
# Name: Ship Mode, dtype: float64

# %%
# Nominal

# %%
data['Customer Name'].value_counts(normalize=True, dropna=False)
# Out:
# William Brown          0.003571
# Matt Abelman           0.003469
# Paul Prost             0.003469
# John Lee               0.003367
# Chloris Kastensmidt    0.003265
#                          ...
# Jocasta Rupert         0.000102
# Carl Jackson           0.000102
# Sung Chung             0.000102
# Ricardo Emerson        0.000102
# Anthony O'Donnell      0.000102
# Name: Customer Name, Length: 793, dtype: float64

# %%
data['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
data['Segment'].value_counts(normalize=True, dropna=False)
# Out:
# Consumer       0.520510
# Corporate      0.301327
# Home Office    0.178163
# Name: Segment, dtype: float64

# %%
data['City'].value_counts(normalize=True, dropna=False)
# Out:
# New York City    0.090918
# Los Angeles      0.074286
# Philadelphia     0.054286
# San Francisco    0.051020
# Seattle          0.043469
#                    ...
# San Mateo        0.000102
# Cheyenne         0.000102
# Conway           0.000102
# Melbourne        0.000102
# Springdale       0.000102
# Name: City, Length: 529, dtype: float64

# %%
data['State'].value_counts(normalize=True, dropna=False)
# Out:
# California              0.198571
# New York                0.111939
# Texas                   0.099286
# Pennsylvania            0.059388
# Washington              0.051429
# Illinois                0.049286
# Ohio                    0.046327
# Florida                 0.038061
# Michigan                0.025816
# North Carolina          0.025204
# Virginia                0.022857
# Arizona                 0.022755
# Tennessee               0.018673
# Colorado                0.018265
# Georgia                 0.018061
# Kentucky                0.013980
# Indiana                 0.013776
# Massachusetts           0.013776
# Oregon                  0.012449
# New Jersey              0.012449
# Maryland                0.010714
# Wisconsin               0.010714
# Delaware                0.009490
# Minnesota               0.009082
# Connecticut             0.008367
# Missouri                0.006735
# Oklahoma                0.006735
# Alabama                 0.006224
# ...

# %%
data['Region'].value_counts(normalize=True, dropna=False)
# Out:
# West       0.320408
# East       0.284184
# Central    0.232347
# South      0.163061
# Name: Region, dtype: float64

# %%
data['Category'].value_counts(normalize=True, dropna=False)
# Out:
# Office Supplies    0.602959
# Furniture          0.212041
# Technology         0.185000
# Name: Category, dtype: float64

# %%
data['Sub-Category'].value_counts(normalize=True, dropna=False)
# Out:
# Binders        0.152245
# Paper          0.136531
# Furnishings    0.095000
# Phones         0.089388
# Storage        0.084898
# Art            0.080102
# Accessories    0.077143
# Chairs         0.061939
# Appliances     0.046837
# Labels         0.036429
# Tables         0.032041
# Envelopes      0.025306
# Bookcases      0.023061
# Fasteners      0.021837
# Supplies       0.018776
# Machines       0.011735
# Copiers        0.006735
# Name: Sub-Category, dtype: float64

# %%
#Numerical

# %%
data['Postal Code']=data['Postal Code'].astype('int')

# %%
# Date Time Column

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'], format='%d/%m/%Y')
data['Ship Date'] = pd.to_datetime(data['Ship Date'], format='%d/%m/%Y')

data['Ship Year'] = data['Ship Date'].dt.year
data['Ship Month'] = data['Ship Date'].dt.month
data['Ship date'] = data['Ship Date'].dt.day

data['Order Year'] = data['Order Date'].dt.year
data['Order Month'] = data['Order Date'].dt.month
data['Order date'] = data['Order Date'].dt.day

# %%
data.drop(['Order Date', 'Ship Date'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ship Mode      9800 non-null   object
#  1   Customer Name  9800 non-null   object
#  2   Segment        9800 non-null   object
#  3   City           9800 non-null   object
#  4   State          9800 non-null   object
#  5   Postal Code    9800 non-null   int32
#  6   Region         9800 non-null   object
#  7   Category       9800 non-null   object
#  8   Sub-Category   9800 non-null   object
#  9   Sales          9800 non-null   float64
#  10  Ship Year      9800 non-null   int64
#  11  Ship Month     9800 non-null   int64
#  12  Ship date      9800 non-null   int64
#  13  Order Year     9800 non-null   int64
#  14  Order Month    9800 non-null   int64
#  15  Order date     9800 non-null   int64
# dtypes: float64(1), int32(1), int64(6), object(8)
# memory usage: 1.2+ MB

# %%
#### Univariate Analysis ######

# %%
#Categorical :-

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(1)
plt.subplot(241)
sns.set_theme(style="darkgrid")
data['Ship Mode'].value_counts(normalize=True, dropna=False).plot.bar(figsize=(11,8), title='Ship Mode', color='C5');

plt.subplot(242)
sns.set_theme(style="darkgrid")
data['Segment'].value_counts(normalize=True, dropna=False).plot.bar(figsize=(11, 8), title='Segment', color='C6');

plt.subplot(243)
sns.set_theme(style="darkgrid")
data['Region'].value_counts(normalize=True, dropna=False).plot.bar(figsize=(11,8), title='Region', color='C7');

plt.subplot(244)
sns.set_theme(style="darkgrid")
data['Category'].value_counts(normalize=True, dropna=False).plot.bar(figsize=(11,8), title='Category', color='C8');
plt.tight_layout()

# %%
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

plt.figure(1) 
plt.subplot(121) 
sns.kdeplot(df['Sales'], color='C1'); 

plt.subplot(122) 
data['Sales'].plot.box(figsize=(8,4)) 

plt.tight_layout()

# %%
# Histogram of Sales
plt.figure(figsize=(10, 6))
sns.histplot(data['Sales'], bins=20, kde=True)
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar chart of Ship Mode counts
plt.figure(figsize=(8, 5))
sns.countplot(x='Ship Mode', data=data)
plt.title('Count of Ship Modes')
plt.xlabel('Ship Mode')
plt.ylabel('Count')
plt.show()

# %%
# Seasonal Decompose

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
daily_sales.index = pd.to_datetime(daily_sales.index)
daily_sales = daily_sales.interpolate(method='linear')
daily_sales = daily_sales.asfreq('D')
decomposition = seasonal_decompose(daily_sales, model='additive')

plt.figure(figsize=(12, 8))
plt.subplot(411)
plt.plot(decomposition.trend)
plt.title('Trend')
plt.subplot(412)
plt.plot(decomposition.seasonal)
plt.title('Seasonality')
plt.subplot(413)
plt.plot(decomposition.resid)
plt.title('Residuals')
plt.subplot(414)
plt.plot(daily_sales, label='Original')
plt.legend(loc='best')
plt.title('Original')
plt.tight_layout()
plt.show()

# %%
# Sales over time

# %%
daily_sales=df.groupby('Order Date')['Sales'].sum()
plt.figure(figsize=(12,6))
daily_sales.plot()
plt.title('Daily Sales Over Time')
plt.xlabel('Order Date')
plt.ylabel('sales')
plt.grid(True)
plt.show()

# %%
# Bivariate Analysis

# %%
# Average sales/month for the store

# %%
monthly_sales = pd.DataFrame(data.groupby('Order Month')['Sales'].sum()).reset_index()
plt.figure(figsize=(5, 3))
sns.barplot(x = 'Order Month', y = 'Sales',data = monthly_sales)
plt.xticks(rotation=90)
plt.show()

# %%
yearly_sales = pd.DataFrame(data.groupby('Order Year')['Sales'].sum()).reset_index()
plt.figure(figsize=(3, 3))
sns.barplot(x = 'Order Year', y = 'Sales',data = yearly_sales)
plt.xticks(rotation=90)
plt.show()

# %%
daily_sales = pd.DataFrame(data.groupby('Order date')['Sales'].sum()).reset_index()
plt.figure(figsize=(8, 3))
sns.barplot(x = 'Order date', y = 'Sales',data = daily_sales)
plt.xticks(rotation=90)
plt.show()

# %%
#Most order category per region-

# %%
plt.figure(figsize=(5, 3))
data.groupby('Region')['Category'].value_counts().plot(kind='barh',title='Quantity that has been sold');

# %%
#State have the highest sales

# %%
plt.figure(figsize=(7, 5))
data['State'].value_counts().head(10).plot(kind='pie', autopct='%1.1f%%', colors=sns.color_palette("rocket"), textprops={'weight':'bold', 'color':'#8A8D8F'}) #creates a pie chart
plt.show();

# %%
#State have the lowest sales

# %%
plt.figure(figsize=(7, 5))
data['State'].value_counts().tail(10).plot(kind='pie', autopct='%1.1f%%', colors=sns.color_palette("rocket"), textprops={'weight':'bold', 'color':'#8A8D8F'}) #creates a pie chart
plt.show();

# %%
plt.figure(1)
fig, ax = plt.subplots(2, 2, figsize=(10,4))
plt.subplot(121)
sns.set_theme(style="darkgrid")
sns.countplot(data=data, x = 'City', order = data["City"].value_counts().head(10).index);
plt.xticks(rotation=90)

plt.subplot(122)
sns.set_theme(style="darkgrid")
sns.countplot(data=data, x = 'City', order = data["City"].value_counts().tail(10).index);
plt.xticks(rotation=90)

plt.tight_layout();

# %%
 #The top demanded product in United States

# %%
category_sales = pd.DataFrame(data.groupby('Category')['Sales'].sum()).reset_index()
plt.figure(figsize=(3, 3))
sns.barplot(x = 'Category', y = 'Sales',data = category_sales)
plt.xticks(rotation=45)
plt.show()

# %%
#Sales for each Region-

# %%
region_sales = pd.DataFrame(data.groupby('Region')['Sales'].sum()).reset_index()
plt.figure(figsize=(3, 3))
sns.barplot(x = 'Region', y = 'Sales',data = region_sales)
plt.xticks(rotation=45)
plt.show()

# %%
 # outliers

# %%
data['Sales'].plot.box(figsize=(5,4));

# %%
IQR= data['Sales'].quantile(0.75) - data['Sales'].quantile(0.25)
lower_bridge= data['Sales'].quantile(0.25)-(IQR*1.5)
upper_bridge= data['Sales'].quantile(0.75)+(IQR*1.5)
data.loc[data['Sales']>upper_bridge,'Sales'] = upper_bridge

# %%
data['Sales'].plot.box(figsize=(5,4));

# %%
# Heatmap

# %%
matrix=data.corr()
f,ax=plt.subplots()
sns.heatmap(matrix,vmax=1,square=True,cmap='YlGn')
plt.show()

# %%
# Scatter plot of Sales vs Segment
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sales', y='Segment', data=df, hue='Category')
plt.title('Sales vs Segment')
plt.xlabel('Sales')
plt.ylabel('Segment')
plt.show()

# %%
# Violin plot of Sales distribution by Category
plt.figure(figsize=(12, 8))
sns.violinplot(x='Category', y='Sales', data=df)
plt.title('Sales Distribution by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %%
# Count plot of Sub-Category
plt.figure(figsize=(12, 8))
sns.countplot(x='Sub-Category', data=df, order=df['Sub-Category'].value_counts().index)
plt.title('Count of Sub-Categories')
plt.xlabel('Sub-Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
